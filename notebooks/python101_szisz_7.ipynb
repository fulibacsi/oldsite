# %% [markdown]
# # Python 101 @ SzISz VII.

# %% [markdown]
# ---

# %% [markdown]
# ## Today: Web Scraping II.

# %% [markdown]
# ### Act I: scrape the hungarian tenders

# %%
# import the necessary libraries
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# Let's get some nasty data!

# %%
# store some general data
BASE_URL = 'http://kozbeszerzes.ceu.hu'
kozgep_suburl = '/entity/t/10950676.xml'

# %%
# download raw data
kozgep_response = requests.get(BASE_URL + kozgep_suburl)
print kozgep_response.status_code
# Out:
# 200

# %%
# print what did we get
soup = BeautifulSoup(kozgep_response.content)
print soup.prettify()
# Out:
# <html>
#  <body>
#   <entity city="Budapest" id="t_10950676" name="KÖZGÉP Zrt" url="/entity/t/10950676.xml">
#    <all_known_names>
#     <name>
#      KÖZGÉP Építő- és Fémszerkezetgyártó Zrt,
#     </name>
#     <name>
#      Közgép Építő - és Fémszerkezetgyártó Zrt.
#     </name>
#     <name>
#      Közgép Zrt.
#     </name>
#     <name>
#      KÖZGÉP-UNIÓ Gép- és Fémszerkezetgyártó Rt.
#     </name>
#     <name>
#      KÖZGÉP Építő és Fémszerkezetgyártó Zrt.
#     </name>
#     <name>
#      Magyarország;KÖZGÉP Zrt.
#     </name>
#     <name>
#      Közép Építő- és Fémszerkezetgyártó Zrt.
#     </name>
#     <name>
#      KÖZGÉP Gép- és Fémszerkezetgyártó Rt.
#     </name>
#     <name>
#      Tagok: KÖZGÉP Zrt.
#     </name>
#     <name>
#      KÖZÉP-UNIÓ Rt.
#     </name>
#     <name>
#      Magyarország KÖZGÉP Zrt.
#     </name>
#     <name>
#      Konzorciumvezető: Közgép Építő- és Fémszerkezetgyártó Zrt.
#     </name>
#     <name>
#      Közgép Építő, és Fémszerkezetgyártó Zrt.
#     </name>
#     <name>
#      Közgép Építő-, és Fémszerkezetgyártó Zrt.
#     </name>
#     <name>
#      KÖZGÉP Építő- és Fémszerkezet- Gyártó Zrt.
#     </name>
#     <name>
#      KÖZGÉP Építő- és Fémszerkezetgyártó Zártkörűen Működő Részvénytársaság
#     </name>
#     <name>
#      KÖZGÉP Építő-és Fémszerkezetgyártó Zrt.
#     </name>
#     <name>
#      Magyarország KÖZGÉP Zrt
#     </name>
#     <name>
#      Közgép Építő és Fémszerkezetgyártó Zrt.
#     </name>
#     <name>
#      KÖZGÉP Építő- és Fémszerkezetgyártó Zrt
#     </name>
#     <name>
#      KÖZGÉP Építő és Fémszerkezet Gyártó Rt.
#     </name>
#     <name>
#      KÖZGÉP Rt.
#     </name>
#     <name>
#      KÖZGÉP Zrt
#     </name>
#     <name>
#      Közgép Unió Rt.
#     </name>
#     <name>
#      KMC-2012 Konzorcium; Közgép Építő-, és Fémszerkezetgyártó Zrt.
#     </name>
#     <name>
#      Közgép Építő,-és Fémszerkezetgyártó Zrt.
#     </name>
#     <name>
#      Magyarország); KÖZGÉP Építő- és Fémszerkezetgyártó Zrt.
#     </name>
#     <name>
#      KÖZGÉP Építő- és Fémszerkezetgyártó Zrt.
#     </name>
#     <name>
#      Közgép Építő-és Fémszerkezetgyártó Zrt.
#     </name>
#     <name>
#      KÖZGÉP ZRT.
#     </name>
#     <name>
#      KÖZGÉP Építő - és Fémszerkezetgyártó Zrt.
#     </name>
#     <name>
#      KÖZGÉP Építő-, és Fémszerkezetgyártó Zrt.
#     </name>
#     <name>
#      KŐZGÉP Építő és Fémszerkezetgyártó Zrt.
#     </name>
#     <name>
#      Közgép Rt.
#     </name>
#     <name>
#      Közgép Építő- és Fémszerkezetgyártó Zrt.
#     </name>
#     <name>
#      Közgép Építı-, és Fémszerkezetgyártó Zrt.
#     </name>
#     <name>
#      Közgép-Unió Rt.
#     </name>
#     <name>
#      KÖZGÉP Építő és Fémszerkezetgyártó Kft.
#     </name>
#     <name>
#      Közgép Építő- és Fémszerkezetgyártó Zrt
#     </name>
#     <name>
#      Közgép Zártkörűen Működő Részvénytársaság
#     </name>
#     <name>
#      KÖZGÉP-UNIÓ Rt.
#     </name>
#     <name>
#      Közös Ajánlattevő: KÖZGÉP Építő-, és Fémszerkezetgyártó Zrt.
#     </name>
#     <name>
#      KÖZGÉP Zrt,
#     </name>
#     <name>
#      Közgép Építő,- és Fémszerkezetgyártó Zrt.
#     </name>
#     <name>
#      KÖZGÉP Zrt.
#     </name>
#     <name>
#      Vezető: KÖZGÉP Építő-, és Fémszerkezetgyártó Zrt.
#     </name>
#     <name>
#      Közgép Építő-, és Fémszerkezetgyártó Zrt
#     </name>
#     <name>
#      KÖZGÉP építő- és Fémszerkezetgyártó Zártkörűen Működő Részvénytársaság (konzorciumvezető) és CSŐSZER Paks Épületgépészeti Korlátolt felelősségű Társaság (konzorciumi tag) (közös ajánlattevő: VÍZREKO 2013 KONZORCIUM)
#     </name>
#     <name>
#      KÖZGÉP UNIÓ Rt.
#     </name>
#    </all_known_names>
#    <resolved_addresses>
#     <whitelistaddress>
#      <city>
#       budapest
#      </city>
#      <postalcode>
#       1209
#      </postalcode>
#      <street>
#       haraszti út 44.
#      </street>
#     </whitelistaddress>
#    </resolved_addresses>
#    <all_tenders_won>
#     <tender estimated_value="400000000" id="2013_00_157" requestor_city="Budapest" requestor_name="MÁV Rt" source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_157_2013" subject="A MÁV Zrt. vasúti hidak és acélszerkezetek felújítása és állagmegóvása - kivitelezés tárgyú keretmegállapodás alapján az alábbi munkák vállalkozásba adása : 5B. RÉSZ (MÁV VII. csomag / B rész)" url="/tender/2013/00/157.xml" year="2013">
#      <part bestguess="345803000" id="2013_00_157_1">
#      </part>
#     </tender>
#     <tender estimated_value="1915704" id="2012_00_11695" requestor_city="Budapest" requestor_name="Magyar Közút Zrt." source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_11695_2012" subject="vállalkozási szerződés" url="/tender/2012/00/11695.xml" year="2012">
#      <part bestguess="1022112" id="2012_00_11695_1">
#      </part>
#     </tender>
#     <tender estimated_value="2246326000" id="2011_00_8803" requestor_city="Budapest" requestor_name="Magyar Közút Zrt." source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_8803_2011" subject="”Keretmegállapodások megkötése az Útpénztár finanszírozású nagyfelületi javítási és útfelújítási feladatokra az országos közúthálózaton 2010-2011.”" url="/tender/2011/00/8803.xml" year="2011">
#      <part bestguess="1985007000" id="2011_00_8803_5">
#      </part>
#      <part bestguess="2324762000" id="2011_00_8803_6">
#      </part>
#     </tender>
#     <tender estimated_value="437000000" id="2007_00_15485" requestor_city="Hódmezővásárhely" requestor_name="Hódmezővásárhely Megyei Jogú Város Önkormányzat" source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_15485_2007" subject="Ipari út építése." url="/tender/2007/00/15485.xml" year="2007">
#      <part bestguess="483250000.0" id="2007_00_15485_1">
#      </part>
#     </tender>
#     <tender estimated_value="" id="2002_28_5592" requestor_city="Budapest" requestor_name="KHVT Kht." source_url="http://regi.kozbeszerzes.hu/static/KEarchiv/0228/5592.html" subject='közúti TS uszályhídhoz kettő db - 25 m támaszközű, az MSZ-07-3701 szerinti "A" jelű terhelési osztályú, egy forgalmi sáv szélességű, a vonatkozó szabványok útügyi műszaki szabályzatok és előírások előírásainak, valamint a dokumentációban részletezett követelményeknek megfelelő, a meglévő bejáróhidak helyettesítésére alkalmas és önálló hídprovizóriumként is használható - bejáróhíd tervezése és gyártása.' url="/tender/2002/28/5592.xml" year="2002">
#      <part bestguess="34495000" id="2002_28_5592_1">
#      </part>
#     </tender>
#     <tender estimated_value="4550616201" id="2013_00_1360" requestor_city="Tatabánya" requestor_name="Duna-Vértes Köze Regionális Hulladékgazdálkodási Társulás" source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_1360_2013" subject="A „Települési szilárdhulladék-lerakók rekultivációja a Duna-Vértes Köze Regionális Hulladékgazdálkodási Társulás területén” tárgyú, KEOP-2.3.0/2F/09-2010-0014 azonosító számú projekthez kapcsolódó építési munkálatok elvégzése FIDIC Piros Könyv „Építési munkák szerződéses feltételei, 2005 (Új Piros Könyv)” alapján" url="/tender/2013/00/1360.xml" year="2013">
#      <part bestguess="4472702046" id="2013_00_1360_1">
#      </part>
#     </tender>
#     <tender estimated_value="7242000000" id="2013_00_23476" requestor_city="Budaörs" requestor_name="Radioaktív Hulladékokat Kezelő Kft." source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_23476_2013" subject="A Bodai Agyagkő Formáció (BAF) földtani kutatása, az I. Felszíni kutatási fázis 2." url="/tender/2013/00/23476.xml" year="2013">
#      <part bestguess="7873502250" id="2013_00_23476_1">
#      </part>
#     </tender>
#     <tender estimated_value="" id="2011_00_7654" requestor_city="Budapest" requestor_name="Magyar Közút Zrt." source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_7654_2011" subject="Bács-Kiskun megye" url="/tender/2011/00/7654.xml" year="2011">
#      <part bestguess="30238208" id="2011_00_7654_2">
#      </part>
#      <part bestguess="20804501" id="2011_00_7654_3">
#      </part>
#      <part bestguess="35586616" id="2011_00_7654_13">
#      </part>
#      <part bestguess="100538647" id="2011_00_7654_17">
#      </part>
#      <part bestguess="23716203" id="2011_00_7654_18">
#      </part>
#      <part bestguess="30987176" id="2011_00_7654_20">
#      </part>
#      <part bestguess="16416541" id="2011_00_7654_21">
#      </part>
#      <part bestguess="13396531" id="2011_00_7654_27">
#      </part>
#      <part bestguess="26305217" id="2011_00_7654_32">
#      </part>
#      <part bestguess="85742454" id="2011_00_7654_35">
#      </part>
#      <part bestguess="27645487" id="2011_00_7654_38">
#      </part>
#      <part bestguess="33471969" id="2011_00_7654_40">
#      </part>
#     </tender>
#     <tender estimated_value="3300000000" id="2013_00_2812" requestor_city="Paks" requestor_name="MVM Paksi Atomerőmű Zrt." source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_2812_2013" subject="Vállalkozási szerződés / Technológiai épületekhez és rendszerekhez kapcsolódó korrózió elleni bevonatok, dekontaminálható bevonatrendszerek készítése és javítása 2013-2017." url="/tender/2013/00/2812.xml" year="2013">
#      <part bestguess="3447901272" id="2013_00_2812_1">
#      </part>
#     </tender>
#     <tender estimated_value="" id="2012_00_9199" requestor_city="Mosonmagyaróvár" requestor_name="Mosonmagyaróvár Nagytérségi Hulladékgazdálkodási Önkormányzati Társulás" source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_9199_2012" subject="Vállalkozási szerződés - A Mosonmagyaróvári Nagytérségi Települési Szilárd-hulladékgazdálkodási Rendszer Fejlesztése projekt (KEOP-1.1.1/2F/09-2010-0007) keretében a jánossomorjai hulladékválogató- és kezelőmű teljes körű kivitelezése az ajánlattételi dokumentációban meghatározottak, illetőleg a FIDIC sárga könyv szerződéses feltételei szerint." url="/tender/2012/00/9199.xml" year="2012">
#      <part bestguess="1459303429" id="2012_00_9199_1">
#      </part>
#     </tender>
#     <tender estimated_value="" id="2010_00_7735" requestor_city="Budapest" requestor_name="Magyar Közút Zrt." source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_7735_2010" subject="Hídfelújítások II. 2010" url="/tender/2010/00/7735.xml" year="2010">
#      <part bestguess="306564383" id="2010_00_7735_2">
#      </part>
#     </tender>
#     <tender estimated_value="175000000" id="2013_00_2422" requestor_city="Paks" requestor_name="MVM Paksi Atomerőmű Zrt." source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_2422_2013" subject="Vállalkozási szerződés/Gépházi csurgalékvíz-elvezető rendszer rekonstrukciója" url="/tender/2013/00/2422.xml" year="2013">
#      <part bestguess="249593969" id="2013_00_2422_1">
#      </part>
#     </tender>
#     <tender estimated_value="120000000" id="2013_00_150" requestor_city="Budapest" requestor_name="MÁV Rt" source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_150_2013" subject="A MÁV Zrt. vasúti hidak és acélszerkezetek felújítása és állagmegóvása - kivitelezés : 1B1 RÉSZ (MÁV II. csomag / B1 rész)" url="/tender/2013/00/150.xml" year="2013">
#      <part bestguess="249999674" id="2013_00_150_3">
#      </part>
#      <part bestguess="392387071" id="2013_00_150_4">
#      </part>
#     </tender>
#     <tender estimated_value="" id="2002_24_4337" requestor_city="Budapest" requestor_name="KHVT Kht." source_url="http://regi.kozbeszerzes.hu/static/KEarchiv/0224/4337.html" subject="közúti TS uszályhíd bejáróhídhoz - 8 db áthidaló elem, - 8 db éktest, - 16 db saru és tartozékok gyártása." url="/tender/2002/24/4337.xml" year="2002">
#      <part bestguess="23643680.0" id="2002_24_4337_1">
#      </part>
#     </tender>
#     <tender estimated_value="436160397" id="2011_00_31190" requestor_city="Kondoros" requestor_name="Kondoros Város Önkormányzata" source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_31190_2011" subject="Keretmegállapodás a „Belvízrendezés az élhetőbb településekért, komplex belvízrendezési program megvalósítása a belterületen és a csatlakozó társulati csatornán I. ütem” azonosító szám: DAOP 5.2.1. / D-2008-0002” elnevezésű projekt 1. részére" url="/tender/2011/00/31190.xml" year="2011">
#      <part bestguess="36299170" id="2011_00_31190_1">
#      </part>
#      <part bestguess="25152937" id="2011_00_31190_2">
#      </part>
#      <part bestguess="15512012" id="2011_00_31190_3">
#      </part>
#     </tender>
#     <tender estimated_value="6000000000" id="2009_00_26598" requestor_city="Budapest" requestor_name="Kulturális Örökségvédelmi Szakszolgálat" source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_26598_2009" subject='"Nagyberuházásokhoz kapcsolódó megelőző régészeti feltárások gépi és kézi földmunkája"' url="/tender/2009/00/26598.xml" year="2009">
#      <part bestguess="6000000000" id="2009_00_26598_1">
#      </part>
#     </tender>
#     <tender estimated_value="3931443402" id="2012_00_5937" requestor_city="Eger" requestor_name="Heves Megyei Regionális Hulladékgazdálkodási Társulás" source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_5937_2012" subject="Vállalkozási szerződés keretében a „Heves Megyei Regionális Hulladékgazdálkodási Társulás működési területén bezárt települési szilárdhulladék-lerakók rekultivációja” tárgyú KEOP-2.3.0./2F/09-2010-0028 projekthez kapcsolódó építési kivitelezési munkák ellátása FIDIC Piros könyv szerint." url="/tender/2012/00/5937.xml" year="2012">
#      <part bestguess="3772375877" id="2012_00_5937_1">
#      </part>
#     </tender>
#     <tender estimated_value="321000000" id="2013_00_6185" requestor_city="Budapest" requestor_name="Nemzeti Infrastruktúra Fejlesztő Zrt." source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_6185_2013" subject="M3 gyorsforgalmi út, Nyíregyháza - 49. sz. főút (234+238-268+000 km sz.) közötti szakasz kiegészítő munkáinak elvégzése" url="/tender/2013/00/6185.xml" year="2013">
#      <part bestguess="320999998" id="2013_00_6185_1">
#      </part>
#     </tender>
#     <tender estimated_value="" id="2012_00_10718" requestor_city="Budapest" requestor_name="Magyar Közút Zrt." source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_10718_2012" subject="Egyedi Vállalkozási Szerződés ÉM-27" url="/tender/2012/00/10718.xml" year="2012">
#      <part bestguess="0" id="2012_00_10718_3">
#      </part>
#      <part bestguess="0" id="2012_00_10718_4">
#      </part>
#      <part bestguess="0" id="2012_00_10718_5">
#      </part>
#      <part bestguess="0" id="2012_00_10718_6">
#      </part>
#      <part bestguess="0" id="2012_00_10718_7">
#      </part>
#     </tender>
#     <tender estimated_value="111750927" id="2009_00_5606" requestor_city="Cegléd" requestor_name="DPMG Zrt." source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_5606_2009" subject="DPMG Zrt., állattartó telepek korszerűsítése" url="/tender/2009/00/5606.xml" year="2009">
#      <part bestguess="123098260" id="2009_00_5606_1">
#      </part>
#     </tender>
#     <tender estimated_value="" id="2010_00_31620" requestor_city="Keszthely" requestor_name="Keszthely Város Önkormányzat" source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_31620_2010" subject="Vállalkozási szerződés" url="/tender/2010/00/31620.xml" year="2010">
#      <part bestguess="997644296" id="2010_00_31620_1">
#      </part>
#     </tender>
#     <tender estimated_value="" id="2009_00_10332" requestor_city="Budapest" requestor_name="Fővárosi Vízművek Zrt." source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_10332_2009" subject="Vállalkozási szerződés a Margit híd teljes rekonstrukciójához kapcsolódóan 1220fm +10% DN600 acél ivóvízvezeték felújítására és kapcsolódó ideiglenes ivóvízvezeték építésére, valamint a kiviteli terv elkészítésére." url="/tender/2009/00/10332.xml" year="2009">
#      <part bestguess="174001500" id="2009_00_10332_1">
#      </part>
#     </tender>
#     <tender estimated_value="" id="2010_00_33965" requestor_city="Keszthely" requestor_name="Keszthely Város Önkormányzat" source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_33965_2010" subject="Vállalkozási szerződés" url="/tender/2010/00/33965.xml" year="2010">
#      <part bestguess="997644296" id="2010_00_33965_1">
#      </part>
#     </tender>
#     <tender estimated_value="520000000" id="2011_00_32703" requestor_city="Budapest" requestor_name="MÁV Rt" source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_32703_2011" subject="A MÁV Zrt. vasúti hidak és acélszerkezetek felújítása és állagmegóvása - kivitelezés (MÁV II. csomag / A rész)" url="/tender/2011/00/32703.xml" year="2011">
#      <part bestguess="519348656" id="2011_00_32703_1">
#      </part>
#      <part bestguess="600000000" id="2011_00_32703_2">
#      </part>
#      <part bestguess="406438175" id="2011_00_32703_6">
#      </part>
#      <part bestguess="549535202" id="2011_00_32703_8">
#      </part>
#     </tender>
#     <tender estimated_value="80000000" id="2012_00_3591" requestor_city="Budapest" requestor_name="GYSEV Zrt." source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_3591_2012" subject="FKG szabályozás és KIAG feladatok ellátása a GYSEV Zrt. részére”" url="/tender/2012/00/3591.xml" year="2012">
#      <part bestguess="80000000.0" id="2012_00_3591_1">
#      </part>
#      <part bestguess="40000000.0" id="2012_00_3591_2">
#      </part>
#      <part bestguess="35000000.0" id="2012_00_3591_3">
#      </part>
#     </tender>
#     <tender estimated_value="30250300" id="2012_00_6682" requestor_city="Budapest" requestor_name="Nemzeti Infrastruktúra Fejlesztő Zrt." source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_6682_2012" subject="Vállalkozási szerződés a „41. sz. főút 53+474 km szelvényében lévő Vásárosnaményi II. Rákóczi Ferenc Tisza híd átépítése kivitelezési munkáihoz tartozó ellenőrző hely kialakítása”" url="/tender/2012/00/6682.xml" year="2012">
#      <part bestguess="29990000" id="2012_00_6682_1">
#      </part>
#     </tender>
#     <tender estimated_value="71000000" id="2011_00_16603" requestor_city="Budapest" requestor_name="Állami Autópálya Kezelő zrt." source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_16603_2011" subject="M3 havaria hídfelújítás/2011." url="/tender/2011/00/16603.xml" year="2011">
#      <part bestguess="64866400" id="2011_00_16603_1">
#      </part>
#     </tender>
#     <tender estimated_value="258315403" id="2009_00_5512" requestor_city="Sárvár" requestor_name="Szombathelyi Tangazdaság Zrt." source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_5512_2009" subject="Szombathelyi Tangazdaság Zrt., állattartó telepek korszerűsítése, szarvasmarhatelepek." url="/tender/2009/00/5512.xml" year="2009">
#      <part bestguess="257004190" id="2009_00_5512_1">
#      </part>
#     </tender>
#     <tender estimated_value="15000000000" id="2011_00_27791" requestor_city="Budapest" requestor_name="Magyar Közút Zrt." source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_27791_2011" subject="Keretmegállapodás" url="/tender/2011/00/27791.xml" year="2011">
#      <part bestguess="15000000000" id="2011_00_27791_4">
#      </part>
#      <part bestguess="7500000000" id="2011_00_27791_5">
#      </part>
#      <part bestguess="12000000000" id="2011_00_27791_6">
#      </part>
#      <part bestguess="6750000000" id="2011_00_27791_7">
#      </part>
#     </tender>
#     <tender estimated_value="2695000000" id="2011_00_32378" requestor_city="Budapest" requestor_name="Nemzeti Infrastruktúra Fejlesztő Zrt." source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_32378_2011" subject="41. sz. főút 53+474 km szelvényében lévő Vásárosnaményi II. Rákóczi Ferenc Tisza híd átépítése kivitelezési munkáinak elvégzése. A beszerzés projekt és PST kódja/KVM jele: K041.03." url="/tender/2011/00/32378.xml" year="2011">
#      <part bestguess="4235395456" id="2011_00_32378_1">
#      </part>
#     </tender>
#     <tender estimated_value="854000000" id="2007_00_9693" requestor_city="Szolnok" requestor_name="Szolnok Megyei Jogú Város Önkormányzata" source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_9693_2007" subject="Szolnok belvárosának rehabilitációja" url="/tender/2007/00/9693.xml" year="2007">
#      <part bestguess="952393726.667" id="2007_00_9693_1">
#      </part>
#     </tender>
#     <tender estimated_value="505000000" id="2012_00_17282" requestor_city="Budapest" requestor_name="MÁV Rt" source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_17282_2012" subject="A MÁV Zrt. vasúti hidak és acélszerkezetek felújítása és állagmegóvása - kivitelezés : 6A. RÉSZ (MÁV VIII. csomag / A rész)" url="/tender/2012/00/17282.xml" year="2012">
#      <part bestguess="474070700" id="2012_00_17282_1">
#      </part>
#      <part bestguess="241000000" id="2012_00_17282_3">
#      </part>
#     </tender>
#     <tender estimated_value="" id="2011_00_27899" requestor_city="Budapest" requestor_name="Magyar Közút Zrt." source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_27899_2011" subject="Döbröközi Kapos híd helyreállítása" url="/tender/2011/00/27899.xml" year="2011">
#      <part bestguess="25410483" id="2011_00_27899_1">
#      </part>
#     </tender>
#     <tender estimated_value="" id="2003_34_6182" requestor_city="Budapest" requestor_name="KHVT Kht." source_url="http://regi.kozbeszerzes.hu/static/KEarchiv/0334/6182.html" subject="vasúti TS uszályhíd vasúti pályájához 485 fm acél hosszaljnak a dokumentációban részletezett követelményeknek és kiviteli tervnek, valamint a vonatkozó szabványok, műszaki szabályzatok és előírások előírásainak megfelelő gyártása." url="/tender/2003/34/6182.xml" year="2003">
#      <part bestguess="29404300.0" id="2003_34_6182_1">
#      </part>
#     </tender>
#     <tender estimated_value="4400000000" id="2008_00_15120" requestor_city="Őrbottyán" requestor_name="Őrbottyán Város Önkormányzata" source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_15120_2008" subject="" url="/tender/2008/00/15120.xml" year="2008">
#      <part bestguess="4568000000" id="2008_00_15120_1">
#      </part>
#     </tender>
#     <tender estimated_value="4198837500" id="2011_00_168" requestor_city="Nagykőrös" requestor_name="Nagykőrös Város Önkormányzat és Polgármesteri Hivatal" source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_168_2011" subject="Keretmegállapodás keretében KEOP 1.2.0.-Nagykőrös Város Önkormányzat szennyvízcsatorna hálózatának fejlesztése." url="/tender/2011/00/168.xml" year="2011">
#      <part bestguess="4455632114" id="2011_00_168_1">
#      </part>
#     </tender>
#     <tender estimated_value="26921540" id="2009_00_24397" requestor_city="Hódmezővásárhely" requestor_name="Hódmezővásárhely Megyei Jogú Város Önkormányzat" source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_24397_2009" subject="Szent Antal, Hódi Pál és Deák F. utcák járdaburkolat felújítása Hódmezővásárhelyen" url="/tender/2009/00/24397.xml" year="2009">
#      <part bestguess="23597305" id="2009_00_24397_1">
#      </part>
#     </tender>
#     <tender estimated_value="2500000" id="2011_00_10656" requestor_city="Budapest" requestor_name="Magyar Közút Zrt." source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_10656_2011" subject="vállalkozási szerződés" url="/tender/2011/00/10656.xml" year="2011">
#      <part bestguess="3079024" id="2011_00_10656_1">
#      </part>
#     </tender>
#     <tender estimated_value="8974276279" id="2012_00_5419" requestor_city="Pécs" requestor_name="Mecsek-Dráva Önkormányzati Társulás" source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_5419_2012" subject="Mecsek-Dráva Hulladékgazdálkodási Program - Települési szilárdhulladék-gazdálkodási rendszerek fejlesztése tárgyú projekt keretében Regionális Hulladékkezelő Központok létesítése, valamint a szükséges engedélyes és kiviteli tervek elkészítése FIDIC sárga könyv szerinti vállalkozási szerződés alapján." url="/tender/2012/00/5419.xml" year="2012">
#      <part bestguess="9350000000" id="2012_00_5419_1">
#      </part>
#     </tender>
#     <tender estimated_value="" id="2010_00_9241" requestor_city="Budapest" requestor_name="Nemzeti Infrastruktúra Fejlesztő Zrt." source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_9241_2010" subject="KP - 029 Vállalkozási szerződés a 47. sz. főút - 4415 j. út Hódmezővásárhely Kálvin János tér" url="/tender/2010/00/9241.xml" year="2010">
#      <part bestguess="110000000" id="2010_00_9241_1">
#      </part>
#     </tender>
#     <tender estimated_value="" id="2013_00_12022" requestor_city="Budapest" requestor_name="GYSEV Zrt." source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_12022_2013" subject="Bük - Acsád állomásközben hosszúsínek cseréjéhez szükséges vágányon járó bagger bérlése kezelővel a GYSEV Zrt. területén" url="/tender/2013/00/12022.xml" year="2013">
#      <part bestguess="480000" id="2013_00_12022_1">
#      </part>
#      <part bestguess="5924000" id="2013_00_12022_2">
#      </part>
#      <part bestguess="40836837" id="2013_00_12022_3">
#      </part>
#     </tender>
#     <tender estimated_value="" id="2009_00_2197" requestor_city="Győr" requestor_name="Győr Megyei Jogú Város Önkormányzat" source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_2197_2009" subject="Győr, Sziget-Révfalu összekötése új Mosoni-Duna híddal, kapcsolódó utakkal, csomópontokkal és közműépítésekkel, továbbá meglévő Vásárhelyi Pál híd elbontása" url="/tender/2009/00/2197.xml" year="2009">
#      <part bestguess="2588778090.4" id="2009_00_2197_1">
#      </part>
#     </tender>
#     <tender estimated_value="11587500000" id="2013_00_12457" requestor_city="Budapest" requestor_name="Magyar Közút Zrt." source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_12457_2013" subject="„Hazai forrásból finanszírozott 2013-2014 évi nagyfelületű javítási, felújítási és a rendkívüli időjárás okozta burkolatkárok helyreállítására, valamint európai uniós forrásból finanszírozott, főként ROP 2007-2013 programozási időszak tekintetében útfelújítási munkákra keretmegállapodások megkötése”" url="/tender/2013/00/12457.xml" year="2013">
#      <part bestguess="12510000000" id="2013_00_12457_4">
#      </part>
#      <part bestguess="8872500000" id="2013_00_12457_5">
#      </part>
#      <part bestguess="7350000000" id="2013_00_12457_6">
#      </part>
#      <part bestguess="5505000000" id="2013_00_12457_7">
#      </part>
#     </tender>
#     <tender estimated_value="23551500000" id="2013_00_18722" requestor_city="Budapest" requestor_name="Nemzeti Infrastruktúra Fejlesztő Zrt." source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_18722_2013" subject="„Békéscsaba vasútállomás pálya, vasúti műtárgyépítési, vasúti felsővezeték, utak építési munkái, valamint a kapcsolódó ideiglenes vasúti biztosítóberendezési, vasút üzemi épületek magasépítészeti, ideiglenes távközlési, külön szintű közút-vasútkeresztezések műtárgyépítési, közműkiváltási, kábelkiváltási munkák tervezése és megvalósítása”" url="/tender/2013/00/18722.xml" year="2013">
#      <part bestguess="34953297082" id="2013_00_18722_1">
#      </part>
#     </tender>
#     <tender estimated_value="255000" id="2006_00_24618" requestor_city="Budapest" requestor_name="Útgazdálkodás i és Koordinációs Igazgatóság" source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_24618_2006" subject="A magyarországi Komárom és a szlovákiai Komárno városok között közúti Duna-híd kiegészítő rekonstrukciós munkái." url="/tender/2006/00/24618.xml" year="2006">
#      <part bestguess="255000" id="2006_00_24618_1">
#      </part>
#     </tender>
#     <tender estimated_value="8400000000" id="2013_00_20212" requestor_city="Budapest" requestor_name="Nemzeti Infrastruktúra Fejlesztő Zrt." source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_20212_2013" subject="K008.16. 8 sz. főút Várpalota - Veszprém között I. szakasz 33+100 - 39+600 km sz. (Pétfürdő - Hajmáskér) 115kN-os burkolat-megerősítési, útkorszerűsítési, valamint a kapcsolódó létesítményeinek kivitelezési feladatainak elvégzése" url="/tender/2013/00/20212.xml" year="2013">
#      <part bestguess="7944923188" id="2013_00_20212_1">
#      </part>
#     </tender>
#     <tender estimated_value="" id="2012_00_16080" requestor_city="Budapest" requestor_name="Magyar Közút Zrt." source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_16080_2012" subject="Egyedi Vállalkozási Szerződés ÉM-28" url="/tender/2012/00/16080.xml" year="2012">
#      <part bestguess="0" id="2012_00_16080_8">
#      </part>
#      <part bestguess="0" id="2012_00_16080_10">
#      </part>
#      <part bestguess="0" id="2012_00_16080_11">
#      </part>
#      <part bestguess="0" id="2012_00_16080_12">
#      </part>
#     </tender>
#     <tender estimated_value="1742491579" id="2013_00_20211" requestor_city="Budapest" requestor_name="Nemzeti Infrastruktúra Fejlesztő Zrt." source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_20211_2013" subject="„68. sz. főút Nagyatád elkerülés kivitelezési munkáinak elvégzése” vállalkozási szerződés keretében" url="/tender/2013/00/20211.xml" year="2013">
#      <part bestguess="2299848328" id="2013_00_20211_1">
#      </part>
#     </tender>
#     <tender estimated_value="6000000000" id="2009_00_19563" requestor_city="Budapest" requestor_name="Kulturális Örökségvédelmi Szakszolgálat" source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_19563_2009" subject="„Nagyberuházásokhoz kapcsolódó megelőző régészeti feltárások gépi és kézi földmunkája ”" url="/tender/2009/00/19563.xml" year="2009">
#      <part bestguess="6000000000" id="2009_00_19563_1">
#      </part>
#     </tender>
#     <tender estimated_value="2246326000" id="2011_00_28417" requestor_city="Budapest" requestor_name="Magyar Közút Zrt." source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_28417_2011" subject="”Keretmegállapodások megkötése az Útpénztár finanszírozású nagyfelületi javítási és útfelújítási feladatokra az országos közúthálózaton 2010-2011.”" url="/tender/2011/00/28417.xml" year="2011">
#      <part bestguess="54140780" id="2011_00_28417_12">
#      </part>
#      <part bestguess="47999030" id="2011_00_28417_13">
#      </part>
#      <part bestguess="47995880" id="2011_00_28417_14">
#      </part>
#      <part bestguess="37603717" id="2011_00_28417_15">
#      </part>
#      <part bestguess="34766080" id="2011_00_28417_16">
#      </part>
#      <part bestguess="45966412" id="2011_00_28417_17">
#      </part>
#     </tender>
#     <tender estimated_value="1948327350" id="2011_00_15671" requestor_city="Kaposvár" requestor_name="Kaposmenti Hulladékgazdálkodási Önkormányzati Társulás" source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_15671_2011" subject="FIDIC Piros könyv szerinti vállalkozási szerződés keretében a Kaposmenti Hulladéklerakó Rekultivációs Program (KEOP 2.3.0./2F/09-2010-0003) megvalósításával kapcsolatos kivitelezés." url="/tender/2011/00/15671.xml" year="2011">
#      <part bestguess="1445716200" id="2011_00_15671_1">
#      </part>
#     </tender>
#     <tender estimated_value="4560000000" id="2011_00_32663" requestor_city="Budapest" requestor_name="MÁV Rt" source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_32663_2011" subject="KERETMEGÁLLAPODÁS MEGKÖTÉSE / A MÁV Zrt. vasúti hidak és acélszerkezetek felújítása és állagmegóvása - kivitelezés" url="/tender/2011/00/32663.xml" year="2011">
#      <part bestguess="4560000000" id="2011_00_32663_2">
#      </part>
#     </tender>
#     <tender estimated_value="" id="2008_00_17786" requestor_city="Budapest" requestor_name="Nemzeti Infrastruktúra Fejlesztő Zrt." source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_17786_2008" subject="Vállalkozási szerződés a 41. sz. főút 53 + 474 km szelvényben lévő vásárosnaményi II. Rákóczi Ferenc Tisza-híd és a csatlakozó ártéri szakaszok felújítási munkáinak elvégzésére" url="/tender/2008/00/17786.xml" year="2008">
#      <part bestguess="1234051592" id="2008_00_17786_1">
#      </part>
#     </tender>
#     <tender estimated_value="" id="2008_00_17784" requestor_city="Budapest" requestor_name="Nemzeti Infrastruktúra Fejlesztő Zrt." source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_17784_2008" subject="Vállalkozási szerződés a 46. sz. főút 41 + 235 km szelvényben lévő endrődi Hármas-Körös-híd (Tsz: 1909) átépítési munkáinak, a 4219. jelű út 69 + 430 km szelvényben lévő gyulai Bárdos-híd (Tsz: 1901) felújítási munkáinak elvégzésére" url="/tender/2008/00/17784.xml" year="2008">
#      <part bestguess="830868663" id="2008_00_17784_1">
#      </part>
#     </tender>
#     <tender estimated_value="" id="2008_00_16490" requestor_city="Salgótarján" requestor_name="Salgótarján Megyei Jogú Város" source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_16490_2008" subject="Vállalkozási szerződések" url="/tender/2008/00/16490.xml" year="2008">
#      <part bestguess="13568729" id="2008_00_16490_1">
#      </part>
#      <part bestguess="27328326" id="2008_00_16490_2">
#      </part>
#      <part bestguess="22193375" id="2008_00_16490_3">
#      </part>
#      <part bestguess="1648956" id="2008_00_16490_4">
#      </part>
#      <part bestguess="2852644" id="2008_00_16490_5">
#      </part>
#     </tender>
#     <tender estimated_value="81600000" id="2009_00_21214" requestor_city="Székesfehérvár" requestor_name="Székesfehérvár Megyei Jogú Város Önkormányzata" source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_21214_2009" subject="RÁDIÓ UTCA ÚTFELÚJÍTÁS, SZIKKASZTÓ ÁROK ÉPÍTÉSSEL" url="/tender/2009/00/21214.xml" year="2009">
#      <part bestguess="7353824" id="2009_00_21214_1">
#      </part>
#     </tender>
#     <tender estimated_value="241000000" id="2012_00_17309" requestor_city="Budapest" requestor_name="GYSEV Zrt." source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_17309_2012" subject="„Porpác 7. számú kitérő cseréje, kitérő aláverés KIAG-gal 247 csoport kitérőn és aljjavítás 13776 aljra (55104 db furat) vonatkozóan”" url="/tender/2012/00/17309.xml" year="2012">
#      <part bestguess="204796213" id="2012_00_17309_1">
#      </part>
#      <part bestguess="15723000" id="2012_00_17309_2">
#      </part>
#     </tender>
#     <tender estimated_value="3804932000" id="2011_00_952" requestor_city="Nagykanizsa" requestor_name="Nagykanizsai Regionális Szennyvíztársulás" source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_952_2011" subject="Az Észak-nyugati, valamint a Dél-nyugati régió csatornahálózat bővítésének kivitelezési munkái" url="/tender/2011/00/952.xml" year="2011">
#      <part bestguess="3786000000" id="2011_00_952_1">
#      </part>
#     </tender>
#     <tender estimated_value="9000000000" id="2013_00_18997" requestor_city="Budapest" requestor_name="Nemzeti Infrastruktúra Fejlesztő Zrt." source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_18997_2013" subject="Vállalkozási szerződés keretén belül a K008.22 8. sz. főút Márkó - Herend (63+778 - 69+055 km sz.) közötti szakasz 115 kN-os burkolat-megerősítési, korszerűsítési, valamint kapcsolódó létesítményeinek kivitelezési feladatainak ellátása." url="/tender/2013/00/18997.xml" year="2013">
#      <part bestguess="8486962936" id="2013_00_18997_1">
#      </part>
#     </tender>
#     <tender estimated_value="8974276279" id="2012_00_7993" requestor_city="Pécs" requestor_name="Mecsek-Dráva Önkormányzati Társulás" source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_7993_2012" subject="Mecsek-Dráva Hulladékgazdálkodási Program - Települési szilárdhulladék-gazdálkodási rendszerek fejlesztése tárgyú projekt keretében Regionális Hulladékkezelő Központok létesítése, valamint a szükséges engedélyes és kiviteli tervek elkészítése FIDIC sárga könyv szerinti vállalkozási szerződés alapján." url="/tender/2012/00/7993.xml" year="2012">
#      <part bestguess="9350000000" id="2012_00_7993_1">
#      </part>
#     </tender>
#     <tender estimated_value="2154735439" id="2013_00_23532" requestor_city="Orosháza" requestor_name="Délkelet-Alföld Regionális Hulladékgazdálkodási Rendszer Létrehozását Célzó Önko" source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_23532_2013" subject="Vállalkozási szerződés a Délkelet-Alföld Regionális Hulladékgazdálkodási Rendszer Létrehozását CélzóÖnkormányzati Társulás területén lévő felhagyott települési szilárdhulladék lerakók rekultivációja (II. ütem)KEOP-2.3.0/2F/09-11-2011-0004 projekt építési munkáinak, az esetleges kiegészítő és aktualizáló tervezésimunkákkal, FIDIC piros könyv szerinti megvalósítására vonatkozóan LOT-1. Vállalkozási szerződés a Délkelet-Alföld Regionális Hulladékgazdálkodási Rendszer Létrehozását CélzóÖnkormányzati Társulás területén lévő felhagyott települési szilárdhulladék lerakók rekultivációja (II. ütem)KEOP-2.3.0/2F/09-11-2011-0004 projekt építési munkáinak, az esetleges kiegészítő és aktualizáló tervezésimunkákkal, FIDIC piros könyv szerinti megvalósítására vonatkozóan LOT-2." url="/tender/2013/00/23532.xml" year="2013">
#      <part bestguess="2081272782" id="2013_00_23532_1">
#      </part>
#      <part bestguess="1790982248" id="2013_00_23532_2">
#      </part>
#     </tender>
#     <tender estimated_value="91846699" id="2009_00_12317" requestor_city="Hódmezővásárhely" requestor_name="Hódmezővásárhely Megyei Jogú Város Önkormányzat" source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_12317_2009" subject="Ipari út építéséhez kapcsolódó pótmunka végzése" url="/tender/2009/00/12317.xml" year="2009">
#      <part bestguess="91846699" id="2009_00_12317_1">
#      </part>
#     </tender>
#     <tender estimated_value="1600000000" id="2009_00_17014" requestor_city="Szolnok" requestor_name="Szolnok Megyei Jogú Város Önkormányzata" source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_17014_2009" subject="Vállalkozási szerződés" url="/tender/2009/00/17014.xml" year="2009">
#      <part bestguess="1225000000.0" id="2009_00_17014_1">
#      </part>
#     </tender>
#     <tender estimated_value="236000000" id="2013_00_1050" requestor_city="Budapest" requestor_name="GYSEV Zrt." source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_1050_2013" subject="Körmend gyalogos felüljáró I. ütem" url="/tender/2013/00/1050.xml" year="2013">
#      <part bestguess="236417746" id="2013_00_1050_1">
#      </part>
#     </tender>
#     <tender estimated_value="2520000" id="2011_00_10553" requestor_city="Budapest" requestor_name="Magyar Közút Zrt." source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_10553_2011" subject="vállakozási szerződés" url="/tender/2011/00/10553.xml" year="2011">
#      <part bestguess="1618400" id="2011_00_10553_1">
#      </part>
#     </tender>
#     <tender estimated_value="" id="2011_00_28797" requestor_city="Budapest" requestor_name="Magyar Közút Zrt." source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_28797_2011" subject="Törökkoppány Tabany-patak-híd helyreállítása" url="/tender/2011/00/28797.xml" year="2011">
#      <part bestguess="22572059" id="2011_00_28797_1">
#      </part>
#     </tender>
#     <tender estimated_value="168600000" id="2009_00_24354" requestor_city="Nagykőrös" requestor_name="Nagykőrös Város Önkormányzata" source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_24354_2009" subject="Keretmegállapodás keretében Nagykőrös-Kecskemét összekötő kerékpárút építése, belterületi szakaszokon." url="/tender/2009/00/24354.xml" year="2009">
#      <part bestguess="168549286" id="2009_00_24354_1">
#      </part>
#     </tender>
#     <tender estimated_value="" id="2002_48_9656" requestor_city="Szeged" requestor_name="Csongrád Megyei Állami Közútkezelő Közhasznú Társaság" source_url="http://regi.kozbeszerzes.hu/static/KEarchiv/0248/9656.html" subject="Kódszám: 13.232.03.K.7.1. - híd törzsszáma: 1505 - útszám: 43 - útszelvény: 2+103 - munka jellege: hídfelújítás Mennyisége: a 373 m hosszú, 2,7+15+2,7 m szélességi beosztású, acélszerkezetű közúti hídon végzendő felújítási munkák." url="/tender/2002/48/9656.xml" year="2002">
#      <part bestguess="0" id="2002_48_9656_2">
#      </part>
#     </tender>
#     <tender estimated_value="7037762912" id="2012_00_7910" requestor_city="Budapest" requestor_name="Nemzeti Infrastruktúra Fejlesztő Zrt." source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_7910_2012" subject="„Vállalkozási szerződés a 86. sz. főút Szombathely-Vát szakasz (80+775 - 89+980 km sz.) építési munkáinak elvégzésére”" url="/tender/2012/00/7910.xml" year="2012">
#      <part bestguess="7037138861" id="2012_00_7910_1">
#      </part>
#     </tender>
#     <tender estimated_value="343687000" id="2009_00_9461" requestor_city="Sárvár" requestor_name="Sárvári Mg. Zrt." source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_9461_2009" subject="Sárvári Mezőgazdasági Zrt., állattartó telepek korszerűsítése." url="/tender/2009/00/9461.xml" year="2009">
#      <part bestguess="343671000" id="2009_00_9461_1">
#      </part>
#     </tender>
#     <tender estimated_value="2246326000" id="2011_00_17068" requestor_city="Budapest" requestor_name="Magyar Közút Zrt." source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_17068_2011" subject="”Keretmegállapodások megkötése az Útpénztár finanszírozású nagyfelületi javítási és útfelújítási feladatokra az országos közúthálózaton 2010-2011.”" url="/tender/2011/00/17068.xml" year="2011">
#      <part bestguess="545199204" id="2011_00_17068_28">
#      </part>
#      <part bestguess="327065948" id="2011_00_17068_29">
#      </part>
#      <part bestguess="466742597" id="2011_00_17068_30">
#      </part>
#      <part bestguess="69830902" id="2011_00_17068_31">
#      </part>
#      <part bestguess="44038470" id="2011_00_17068_32">
#      </part>
#      <part bestguess="49023224" id="2011_00_17068_33">
#      </part>
#      <part bestguess="551774984" id="2011_00_17068_34">
#      </part>
#      <part bestguess="397163828" id="2011_00_17068_35">
#      </part>
#      <part bestguess="589493682" id="2011_00_17068_36">
#      </part>
#      <part bestguess="53534680" id="2011_00_17068_37">
#      </part>
#      <part bestguess="59572964" id="2011_00_17068_38">
#      </part>
#      <part bestguess="51305178" id="2011_00_17068_40">
#      </part>
#     </tender>
#     <tender estimated_value="5740000" id="2011_00_10653" requestor_city="Budapest" requestor_name="Magyar Közút Zrt." source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_10653_2011" subject="vállalkozási szerződés" url="/tender/2011/00/10653.xml" year="2011">
#      <part bestguess="1505560" id="2011_00_10653_1">
#      </part>
#     </tender>
#     <tender estimated_value="13000000000" id="2013_00_7986" requestor_city="Budapest" requestor_name="Nemzeti Infrastruktúra Fejlesztő Zrt." source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_7986_2013" subject="Vállalkozási szerződés, melynek tárgya „Az M3 autópálya 49. sz. főút-Vásárosnamény (268+000-279+900 km.sz.) közötti szakasza valamint csatlakozó építményei kivitelezési munkáinak elvégzése”" url="/tender/2013/00/7986.xml" year="2013">
#      <part bestguess="15498989989" id="2013_00_7986_1">
#      </part>
#     </tender>
#     <tender estimated_value="18927000" id="2009_00_30102" requestor_city="Nagykőrös" requestor_name="Nagykőrös Város Önkormányzata" source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_30102_2009" subject="Keretmegállapodás keretében Nagykőrös Béke utca útburkolatának felújítása" url="/tender/2009/00/30102.xml" year="2009">
#      <part bestguess="18404825" id="2009_00_30102_1">
#      </part>
#     </tender>
#     <tender estimated_value="" id="2013_00_18457" requestor_city="Budapest" requestor_name="Magyar Közút Zrt." source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_18457_2013" subject="Egyedi Vállalkozási Szerződés ÉA-24" url="/tender/2013/00/18457.xml" year="2013">
#      <part bestguess="0" id="2013_00_18457_8">
#      </part>
#      <part bestguess="0" id="2013_00_18457_9">
#      </part>
#      <part bestguess="0" id="2013_00_18457_10">
#      </part>
#      <part bestguess="0" id="2013_00_18457_11">
#      </part>
#      <part bestguess="0" id="2013_00_18457_12">
#      </part>
#     </tender>
#     <tender estimated_value="13913000" id="2009_00_24871" requestor_city="Nagykőrös" requestor_name="Nagykőrös Város Önkormányzata" source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_24871_2009" subject="Keretmegállapodás keretében Nagykőrös-Kecskemét összekötő kerékpárút építése, belterületi szakaszokon." url="/tender/2009/00/24871.xml" year="2009">
#      <part bestguess="13905000" id="2009_00_24871_1">
#      </part>
#     </tender>
#     <tender estimated_value="49883000" id="2012_00_9430" requestor_city="Budapest" requestor_name="GYSEV Zrt." source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_9430_2012" subject="„Sopron állomás 21. számú kitérő cseréje és FKG szabályozási munkák 15 450 méter hosszban (fekszint és irány kitűzéssel) elvégzése géplánccal a GYSEV Zrt. területén”" url="/tender/2012/00/9430.xml" year="2012">
#      <part bestguess="41530000" id="2012_00_9430_1">
#      </part>
#      <part bestguess="247691317" id="2012_00_9430_2">
#      </part>
#     </tender>
#     <tender estimated_value="17500000000" id="2013_00_9982" requestor_city="Budapest" requestor_name="Nemzeti Infrastruktúra Fejlesztő Zrt." source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_9982_2013" subject="K085.02. Vállalkozási szerződés a 85. sz. főút Csorna elkerülő szakasz I. ütem (távlati M85-M86) kivitelezésimunkáinak elvégzése tárgyában." url="/tender/2013/00/9982.xml" year="2013">
#      <part bestguess="29988273898" id="2013_00_9982_1">
#      </part>
#     </tender>
#     <tender estimated_value="" id="2012_00_8779" requestor_city="Nyíregyháza" requestor_name="Szabolcs-Szatmár-Bereg Megyei Szilárdhulladék-gazdálkodási Társulás" source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_8779_2012" subject="Vállalkozási szerződés 1. RÉSZ - Rekultivációs területek 1." url="/tender/2012/00/8779.xml" year="2012">
#      <part bestguess="1710548320" id="2012_00_8779_1">
#      </part>
#     </tender>
#     <tender estimated_value="2056172369" id="2013_00_23522" requestor_city="Orosháza" requestor_name="Délkelet-Alföld Regionális Hulladékgazdálkodási Rendszer Létrehozását Célzó Önko" source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_23522_2013" subject="Vállalkozási szerződés a Délkelet-Alföld Regionális Hulladékgazdálkodási Rendszer Létrehozását Célzó Önkormányzati Társulás területén lévő felhagyott települési szilárdhulladék lerakók rekultivációja (I. ütem) KEOP-2.3.0/2F/09-11-2011-0003 projekt építési munkáinak, az esetleges kiegészítő és aktualizáló tervezési munkákkal, FIDIC piros könyv szerinti megvalósítására vonatkozóan LOT-1. Vállalkozási szerződés a Délkelet-Alföld Regionális Hulladékgazdálkodási Rendszer Létrehozását Célzó Önkormányzati Társulás területén lévő felhagyott települési szilárdhulladék lerakók rekultivációja (I. ütem) KEOP-2.3.0/2F/09-11-2011-0003 projekt építési munkáinak, az esetleges kiegészítő és aktualizáló tervezési munkákkal, FIDIC piros könyv szerinti megvalósítására vonatkozóan LOT-2." url="/tender/2013/00/23522.xml" year="2013">
#      <part bestguess="1984885205" id="2013_00_23522_1">
#      </part>
#      <part bestguess="1895354000" id="2013_00_23522_2">
#      </part>
#     </tender>
#     <tender estimated_value="158691708" id="2009_00_8257" requestor_city="Hódmezővásárhely" requestor_name="Hódmezővásárhely Megyei Jogú Város Önkormányzat" source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_8257_2009" subject="A Hódmezővásárhelyi kistérség közösségi közlekedésének fejlesztése" url="/tender/2009/00/8257.xml" year="2009">
#      <part bestguess="166622280" id="2009_00_8257_1">
#      </part>
#     </tender>
# ...
#      </street>
#     </address>
#     <address>
#      <city>
#       Budapest
#      </city>
#      <postalcode>
#       1239
#      </postalcode>
#      <street>
#       Haraszti út 44.); PORR- TEERAG KONZORCIUM (H 1056 , Váci u. 81
#      </street>
#     </address>
#     <address>
#      <city>
#       Budapest
#      </city>
#      <postalcode>
#       1239
#      </postalcode>
#      <street>
#       Haraszti út 44.), 4
#      </street>
#     </address>
#     <address>
#      <city>
#       Székhelye:
#      </city>
#      <postalcode>
#       1239
#      </postalcode>
#      <street>
#       Budapest, Haraszti út 44. 3. ajánlat: Ajánlattevő neve: ORTIZ CONSTRUCCIONES Y PROJECTOS S.A. 28051 Madrid, Avda. Ensanche de Vallecas 44., Spanyolország 4. ajánlat: Ajánlattevő neve: H.F. Wiebe GmbH &amp;Co. KG. D-27313 Dörverden, Bahnhof Str. 45. Üzleti címe: D-28832 Achim, Im Finigen 8
#      </street>
#     </address>
#     <address>
#      <city>
#       Tag
#      </city>
#      <postalcode>
#      </postalcode>
#      <street>
#       2
#      </street>
#     </address>
#     <address>
#      <city>
#       Budapest
#      </city>
#      <postalcode>
#       1135
#      </postalcode>
#      <street>
#       Szegedi út 35-37
#      </street>
#     </address>
#     <address>
#      <city>
#       Budapest
#      </city>
#      <postalcode>
#       1113
#      </postalcode>
#      <street>
#       Daróci út 30. (Közös ajánlattevők címe: , Daróci út 30. és 1239 , Haraszti út 44
#      </street>
#     </address>
#     <address>
#      <city>
#       Budapest
#      </city>
#      <postalcode>
#       1734
#      </postalcode>
#      <street>
#       Pf. 31
#      </street>
#     </address>
#     <address>
#      <city>
#       Celldömölk
#      </city>
#      <postalcode>
#       9500
#      </postalcode>
#      <street>
#       Nagy Sándor tér 14. (cím) Magyarország (székhely szerinti ország) 3
#      </street>
#     </address>
#     <address>
#      <city>
#       Budapest
#      </city>
#      <postalcode>
#       1239
#      </postalcode>
#      <street>
#       XXIII., Haraszti u. 44., Magyarország Azok a részek, melyekre ajánlatot nyújtott be: 1., 2., 3., 4., 5., 6
#      </street>
#     </address>
#     <address>
#      <city>
#       Budapest
#      </city>
#      <postalcode>
#       1239
#      </postalcode>
#      <street>
#       Haraszti út 44. Magyarország; Cs T-H 2008
#      </street>
#     </address>
#     <address>
#      <city>
#       Tag
#      </city>
#      <postalcode>
#      </postalcode>
#      <street>
#       2: OMS ROMANIA SRL., 3
#      </street>
#     </address>
#     <address>
#      <city>
#       Budapest
#      </city>
#      <postalcode>
#       1239
#      </postalcode>
#      <street>
#       Haraszti út 44. (közös ajánlattevők nevében eljáró) 2
#      </street>
#     </address>
#     <address>
#      <city>
#       Budapest
#      </city>
#      <postalcode>
#       1239
#      </postalcode>
#      <street>
#       Haraszti út 44. 3
#      </street>
#     </address>
#     <address>
#      <city>
#       Budapest
#      </city>
#      <postalcode>
#       1239
#      </postalcode>
#      <street>
#       Haraszti út 44.), 4. „COLAS M43” Közös Vállalkozás (1033 , Kórház u. 6-12
#      </street>
#     </address>
#     <address>
#      <city>
#       Budapest
#      </city>
#      <postalcode>
#       1239
#      </postalcode>
#      <street>
#       Haraszti u. 44. - Mabey &amp; Johnson Ltd., RG10 9
#      </street>
#     </address>
#     <address>
#      <city>
#       Celldömölk
#      </city>
#      <postalcode>
#       9500
#      </postalcode>
#      <street>
#       Nagy Sándor tér 14
#      </street>
#     </address>
#     <address>
#      <city>
#       Székhelye:
#      </city>
#      <postalcode>
#       1239
#      </postalcode>
#      <street>
#       Budapest, Haraszti út 44
#      </street>
#     </address>
#     <address>
#      <city>
#       Budapest
#      </city>
#      <postalcode>
#       1239
#      </postalcode>
#      <street>
#       Haraszti u. 44. 4
#      </street>
#     </address>
#     <address>
#      <city>
#       Budapest
#      </city>
#      <postalcode>
#       1239
#      </postalcode>
#      <street>
#       Haraszti u. 44. Fax: 885-5430
#      </street>
#     </address>
#     <address>
#      <city>
#       Budapest
#      </city>
#      <postalcode>
#      </postalcode>
#      <street>
#       Haraszti u. 44. - HEGYISPORT Club, , Hárshegyi u. 9
#      </street>
#     </address>
#     <address>
#      <city>
#       Budapest,
#      </city>
#      <postalcode>
#       1239
#      </postalcode>
#      <street>
#       Haraszti út 44
#      </street>
#     </address>
#     <address>
#      <city>
#       Budapest
#      </city>
#      <postalcode>
#       1239
#      </postalcode>
#      <street>
#       Haraszti út 44. (cím) Magyarország (székhely szerinti ország) 4
#      </street>
#     </address>
#     <address>
#      <city>
#       Zalakaros
#      </city>
#      <postalcode>
#       8749
#      </postalcode>
#      <street>
#       Jegenye sor 3.m 1239 Budapest, Haraszti út 44. (cím) Magyarország (székhely szerinti ország) 1
#      </street>
#     </address>
#     <address>
#      <city>
#       Zalakaros
#      </city>
#      <postalcode>
#       8749
#      </postalcode>
#      <street>
#       Jegenye sor 3., 1239 Budapest, Haraszti út 44. (cím) Magyarország (székhely szerinti ország) 1
#      </street>
#     </address>
#     <address>
#      <city>
#       Székhely:
#      </city>
#      <postalcode>
#       1239
#      </postalcode>
#      <street>
#       Budapest, Haraszti út 44 II. Rész: 1
#      </street>
#     </address>
#     <address>
#      <city>
#       Székhely:
#      </city>
#      <postalcode>
#       1239
#      </postalcode>
#      <street>
#       Budapest, Haraszti út 44 3.) Ajánlatkérő rögzíti, hogy az ajánlati ár az egyes elvégzendő feladatokra adott egységárak összegéből áll (ezen egységárakon rendelheti meg ajánlatkérő a szükségessé vált feladatokat maximum a rendelkezésre álló keretösszeg erejéig). Nyertes ajánlattevők által adott ajánlati árak I.rész esetében: nettó 169.849.730., II. Rész esetében: 131.046.884
#      </street>
#     </address>
#     <address>
#      <city>
#       Budapest
#      </city>
#      <postalcode>
#       1239
#      </postalcode>
#      <street>
#       Haraszti út 44. 2
#      </street>
#     </address>
#     <address>
#      <city>
#       Budapest
#      </city>
#      <postalcode>
#       1239
#      </postalcode>
#      <street>
#       Haraszti út 44.) 	Ajánlatkérő típusa:	Regionális vagy helyi iroda/hivatal 	Ajánlatkérő fő tevényeségi köre:	Környezetvédelem 	Letöltés:	 Hirdetmény letöltése PDF formátumban EURÓPAI UNIÓ Az Európai Unió Hivatalos Lapjának Kiegészítő Kiadványa 2, rue Mercier, 2985 Luxembourg, Luxemburg Fax +352 2929-42670 E-mail: ojs@publications.europa.eu Információ és online formanyomtatványok: http://simap.europa.eu Tájékoztató az eljárás eredményéről 2004/18/EK irányelv I. SZAKASZ: AJÁNLATKÉRŐ I.1) Név, cím és kapcsolattartási pont(ok) Hivatalos név: Mecsek-Dráva Önkormányzati Társulás Nemzeti azonosító (ha ismert): Postai cím: Széchenyi tér 1. Város: Pécs Postai irányítószám: 7621 Ország: HU Kapcsolattartási pont(ok): Címzett: Papp Gábor Telefon: +36 725555606 E-mail: papp.gabor@mdhp.hu Fax: +36 72443581 Az ajánlatkérő általános címe (URL): www.mdhp.hu A felhasználói oldal címe (URL): Elektronikus hozzáférés az információkhoz (URL): Az ajánlatok és a részvételi jelentkezések elektronikus benyújtása (URL): I.2) Az ajánlatkérő típusa Minisztérium vagy egyéb nemzeti vagy szövetségi hatóság, valamint regionális vagy helyi részlegeik Nemzeti vagy szövetségi iroda/hivatal Regionális vagy helyi hatóság x Regionális vagy helyi iroda/hivatal Közjogi intézmény Európai intézmény/ügynökség vagy nemzetközi szervezet Egyéb (nevezze meg): I.3) Fő tevékenység Általános közszolgáltatások Honvédelem Közrend és biztonság x Környezetvédelem Gazdasági és pénzügyek Egészségügy Lakásszolgáltatás és közösségi rekreáció Szociális védelem Szabadidő, kultúra és vallás Oktatás Egyéb (nevezze meg): I.4) Beszerzés más ajánlatkérők nevében Az ajánlatkérő más ajánlatkérők nevében végzi a beszerzést: nem (igen válasz esetén, ezekre az ajánlatkérőkre vonatkozóan további információkat az A. mellékletben adhat meg) II. SZAKASZ: A SZERZŐDÉS TÁRGYA II.1) Meghatározás II.1.1) A szerződéshez rendelt elnevezés Mecsek-Dráva Hulladékgazdálkodási Program - Települési szilárdhulladék-gazdálkodási rendszerek fejlesztése tárgyú projekt keretében Regionális Hulladékkezelő Központok létesítése, valamint a szükséges engedélyes és kiviteli tervek elkészítése FIDIC sárga könyv szerinti vállalkozási szerződés alapján. II.1.2) A szerződés típusa és a teljesítés helye ( Csak azt a kategóriát válassza - építési beruházás, árubeszerzés vagy szolgáltatásmegrendelés -, amelyik a leginkább megfelel a szerződés vagy közbeszerzés(ek) tárgyának) x Építési beruházás Kivitelezés x Tervezés és kivitelezés Kivitelezés, bármilyen eszközzel, módon, az ajánlatkérő által meghatározott követelményeknek megfelelően Árubeszerzés Adásvétel Lízing Bérlet Részletvétel Ezek kombinációja Szolgáltatásmegrendelés Szolgáltatási kategória száma A szolgáltatási kategóriákat lásd a C1. mellékletben A 17-27. szolgáltatási kategóriákra vonatkozó szerződés esetében (lásd a C1. mellékletet) egyetért-e a hirdetmény közzétételével? A teljesítés helye Pécs-Kökény, Barcs és Marcali NUTS-kód HU231 II.1.3) Keretmegállapodásra és dinamikus beszerzési rendszerre (DBR) vonatkozó információk A hirdetmény keretmegállapodás megkötésére irányul A hirdetmény dinamikus beszerzési rendszeren (DBR) alapuló szerződés(ek)re irányul II.1.4) A szerződés vagy a beszerzés(ek) rövid meghatározása: Közbeszerzés tárgya: Mecsek-Dráva Hulladékgazdálkodási Program - Települési szilárdhulladék-gazdálkodási rendszerek fejlesztése tárgyú projekt keretében Regionális Hulladékkezelő Központok létesítése, valamint a szükséges engedélyes és kiviteli tervek elkészítése FIDIC sárga könyv szerinti vállalkozási szerződés alapján. Közbeszerzés mennyisége: 3 db Regionális Hulladékkezelő Központ létesítmény tervezés-építése a "Vállalkozó által tervezett gépészeti és villamos berendezések tervezése-építése szerződéses feltételei a kiegészítő magas és mélyépítési munkákkal" FIDIC 1999. kiadvány (annak 2001. évi magyar nyelvű fordítása) alapján. I.) Kökény Regionális Hulladékkezelő Központ, főbb mennyiségek: — 1 db 850 000 m³ kapacitású hulladéklerakó tervezése és k ...
#      </street>
#     </address>
#     <address>
#      <city>
#       Konz.
#      </city>
#      <postalcode>
#       1239
#      </postalcode>
#      <street>
#       tag címe: Budapest, Haraszti út 44
#      </street>
#     </address>
#     <address>
#      <city>
#       Budapest
#      </city>
#      <postalcode>
#       1239
#      </postalcode>
#      <street>
#       Haraszti út 44. Magyarország 1
#      </street>
#     </address>
#     <address>
#      <city>
#       Budapest
#      </city>
#      <postalcode>
#       1138
#      </postalcode>
#      <street>
#       Haraszti út 44
#      </street>
#     </address>
#     <address>
#      <city>
#       Budapest
#      </city>
#      <postalcode>
#       1239
#      </postalcode>
#      <street>
#       Haraszti u. 44., Magyarország - „Miskolc 2006 Konzorcium”, 1118 , Budaörsi u. 64
#      </street>
#     </address>
#     <address>
#      <city>
#       Budapest
#      </city>
#      <postalcode>
#       1113
#      </postalcode>
#      <street>
#       Daróczi út 30
#      </street>
#     </address>
#     <address>
#      <city>
#       Budapest
#      </city>
#      <postalcode>
#       1239
#      </postalcode>
#      <street>
#       Haraszti út 44.) (cím) Magyarország (székhely szerinti ország) 2
#      </street>
#     </address>
#     <address>
#      <city>
#       Budapest
#      </city>
#      <postalcode>
#       1239
#      </postalcode>
#      <street>
#       Haraszti út 44.) Konzorciumi tagok: „KE-VÍZ 21
#      </street>
#     </address>
#     <address>
#      <city>
#       H-1239
#      </city>
#      <postalcode>
#       1239
#      </postalcode>
#      <street>
#       Budapest, Haraszti út 44
#      </street>
#     </address>
#     <address>
#      <city>
#       III.
#      </city>
#      <postalcode>
#       2013
#      </postalcode>
#      <street>
#       A projekt támogatási összegének növeléséről a Kormány 1233
#      </street>
#     </address>
#     <address>
#      <city>
#       Budapest
#      </city>
#      <postalcode>
#       1113
#      </postalcode>
#      <street>
#       Daróci út 30. (konzorciumi tagok címe: Daróci út 30. és 1239 , Haraszti út 44.) (cím) Magyarország (székhely szerinti ország) 2
#      </street>
#     </address>
#     <address>
#      <city>
#       KE-VÍZ
#      </city>
#      <postalcode>
#      </postalcode>
#      <street>
#       21
#      </street>
#     </address>
#     <address>
#      <city>
#       Budapest
#      </city>
#      <postalcode>
#       1239
#      </postalcode>
#      <street>
#       Haraszti út 44.); „KE-VÍZ 21.” ZRT. (4400 Nyíregyháza, Vécsey u. 21
#      </street>
#     </address>
#     <address>
#      <city>
#       Magyarország
#      </city>
#      <postalcode>
#       1239
#      </postalcode>
#      <street>
#       Budapest, Haraszti út 44.) - konzorciumvezető; 2
#      </street>
#     </address>
#     <address>
#      <city>
#       Budapest
#      </city>
#      <postalcode>
#       1239
#      </postalcode>
#      <street>
#       Haraszti út 44.) és Pintér Művek - Pintér József EV (6237 Kecel, Rákóczi Ferenc u. 171/2-177
#      </street>
#     </address>
#     <address>
#      <city>
#       Székhelye:
#      </city>
#      <postalcode>
#       1239
#      </postalcode>
#      <street>
#       Budapest, Haraszti út 44. 2
#      </street>
#     </address>
#     <address>
#      <city>
#       Budapest
#      </city>
#      <postalcode>
#       1134
#      </postalcode>
#      <street>
#       Haraszti út 44
#      </street>
#     </address>
#     <address>
#      <city>
#       Budapest (Közgép Zrt.), illetve Algyő (Délút Kft.)
#      </city>
#      <postalcode>
#       1239, illetve 6750
#      </postalcode>
#      <street>
#       Haraszti u. 44.,(Közgép Zrt.) illetve Kastélykert u. 171
#      </street>
#     </address>
#     <address>
#      <city>
#       Üllő
#      </city>
#      <postalcode>
#       2225
#      </postalcode>
#      <street>
#       Zsaróka hegy 053/30. hrsz., 1239 Budapest, Haraszti út 44. (cím) Magyarország (székhely szerinti ország) 2
#      </street>
#     </address>
#     <address>
#      <city>
#       Székhelye:
#      </city>
#      <postalcode>
#       1239
#      </postalcode>
#      <street>
#       Magyarország Budapest, Haraszti út 44
#      </street>
#     </address>
#     <address>
#      <city>
#       Konzorciumi
#      </city>
#      <postalcode>
#       1239
#      </postalcode>
#      <street>
#       tag) (név) HU Budapest, Haraszti út 44. (cím) HU (székhely szerinti ország) 1
#      </street>
#     </address>
#     <address>
#      <city>
#       Budapest
#      </city>
#      <postalcode>
#       1239
#      </postalcode>
#      <street>
#       Haraszti u. 4
#      </street>
#     </address>
#     <address>
#      <city>
#       Budapest
#      </city>
#      <postalcode>
#      </postalcode>
#      <street>
#       XXIII., Haraszti út 44
#      </street>
#     </address>
#     <address>
#      <city>
#       Budapest
#      </city>
#      <postalcode>
#       1239
#      </postalcode>
#      <street>
#       Haraszti út 44., Magyarország, 2
#      </street>
#     </address>
#     <address>
#      <city>
#       Budapest
#      </city>
#      <postalcode>
#       1239
#      </postalcode>
#      <street>
#       Haraszti út.44
#      </street>
#     </address>
#     <address>
#      <city>
#       Magyarország
#      </city>
#      <postalcode>
#       1239
#      </postalcode>
#      <street>
#       Budapest, Haraszti u. 44
#      </street>
#     </address>
#     <address>
#      <city>
#       Budapest
#      </city>
#      <postalcode>
#       1239
#      </postalcode>
#      <street>
#       Haraszti út 44., 3
#      </street>
#     </address>
#     <address>
#      <city>
#       Haraszti
#      </city>
#      <postalcode>
#      </postalcode>
#      <street>
#       út 44.,123
#      </street>
#     </address>
#     <address>
#      <city>
#       Konzorcium
#      </city>
#      <postalcode>
#      </postalcode>
#      <street>
#       tagja:
#      </street>
#     </address>
#     <address>
#      <city>
#       Budapest
#      </city>
#      <postalcode>
#       1113
#      </postalcode>
#      <street>
#       Daróci út 30. (konzorciumi tagok címe: , Daróci út 30. és 1239 , Haraszti út 44
#      </street>
#     </address>
#     <address>
#      <city>
#       HU-1239
#      </city>
#      <postalcode>
#       1239
#      </postalcode>
#      <street>
#       Budapest, Haraszti út 44
#      </street>
#     </address>
#    </all_known_addresses>
#    <all_tenders_requested>
#    </all_tenders_requested>
#   </entity>
#  </body>
# </html>

# %%
# iterate through the tenders
# beautifulsoup can parse xmls too
for tender in soup.find('all_tenders_won').findAll('tender'):
    print BASE_URL + tender['url']
# Out:
# http://kozbeszerzes.ceu.hu/tender/2013/00/157.xml
# http://kozbeszerzes.ceu.hu/tender/2012/00/11695.xml
# http://kozbeszerzes.ceu.hu/tender/2011/00/8803.xml
# http://kozbeszerzes.ceu.hu/tender/2007/00/15485.xml
# http://kozbeszerzes.ceu.hu/tender/2002/28/5592.xml
# http://kozbeszerzes.ceu.hu/tender/2013/00/1360.xml
# http://kozbeszerzes.ceu.hu/tender/2013/00/23476.xml
# http://kozbeszerzes.ceu.hu/tender/2011/00/7654.xml
# http://kozbeszerzes.ceu.hu/tender/2013/00/2812.xml
# http://kozbeszerzes.ceu.hu/tender/2012/00/9199.xml
# http://kozbeszerzes.ceu.hu/tender/2010/00/7735.xml
# http://kozbeszerzes.ceu.hu/tender/2013/00/2422.xml
# http://kozbeszerzes.ceu.hu/tender/2013/00/150.xml
# http://kozbeszerzes.ceu.hu/tender/2002/24/4337.xml
# http://kozbeszerzes.ceu.hu/tender/2011/00/31190.xml
# http://kozbeszerzes.ceu.hu/tender/2009/00/26598.xml
# http://kozbeszerzes.ceu.hu/tender/2012/00/5937.xml
# http://kozbeszerzes.ceu.hu/tender/2013/00/6185.xml
# http://kozbeszerzes.ceu.hu/tender/2012/00/10718.xml
# http://kozbeszerzes.ceu.hu/tender/2009/00/5606.xml
# http://kozbeszerzes.ceu.hu/tender/2010/00/31620.xml
# http://kozbeszerzes.ceu.hu/tender/2009/00/10332.xml
# http://kozbeszerzes.ceu.hu/tender/2010/00/33965.xml
# http://kozbeszerzes.ceu.hu/tender/2011/00/32703.xml
# http://kozbeszerzes.ceu.hu/tender/2012/00/3591.xml
# http://kozbeszerzes.ceu.hu/tender/2012/00/6682.xml
# http://kozbeszerzes.ceu.hu/tender/2011/00/16603.xml
# http://kozbeszerzes.ceu.hu/tender/2009/00/5512.xml
# http://kozbeszerzes.ceu.hu/tender/2011/00/27791.xml
# http://kozbeszerzes.ceu.hu/tender/2011/00/32378.xml
# http://kozbeszerzes.ceu.hu/tender/2007/00/9693.xml
# http://kozbeszerzes.ceu.hu/tender/2012/00/17282.xml
# http://kozbeszerzes.ceu.hu/tender/2011/00/27899.xml
# http://kozbeszerzes.ceu.hu/tender/2003/34/6182.xml
# http://kozbeszerzes.ceu.hu/tender/2008/00/15120.xml
# http://kozbeszerzes.ceu.hu/tender/2011/00/168.xml
# http://kozbeszerzes.ceu.hu/tender/2009/00/24397.xml
# http://kozbeszerzes.ceu.hu/tender/2011/00/10656.xml
# http://kozbeszerzes.ceu.hu/tender/2012/00/5419.xml
# http://kozbeszerzes.ceu.hu/tender/2010/00/9241.xml
# http://kozbeszerzes.ceu.hu/tender/2013/00/12022.xml
# http://kozbeszerzes.ceu.hu/tender/2009/00/2197.xml
# http://kozbeszerzes.ceu.hu/tender/2013/00/12457.xml
# http://kozbeszerzes.ceu.hu/tender/2013/00/18722.xml
# http://kozbeszerzes.ceu.hu/tender/2006/00/24618.xml
# http://kozbeszerzes.ceu.hu/tender/2013/00/20212.xml
# http://kozbeszerzes.ceu.hu/tender/2012/00/16080.xml
# http://kozbeszerzes.ceu.hu/tender/2013/00/20211.xml
# http://kozbeszerzes.ceu.hu/tender/2009/00/19563.xml
# http://kozbeszerzes.ceu.hu/tender/2011/00/28417.xml
# http://kozbeszerzes.ceu.hu/tender/2011/00/15671.xml
# http://kozbeszerzes.ceu.hu/tender/2011/00/32663.xml
# http://kozbeszerzes.ceu.hu/tender/2008/00/17786.xml
# http://kozbeszerzes.ceu.hu/tender/2008/00/17784.xml
# http://kozbeszerzes.ceu.hu/tender/2008/00/16490.xml
# http://kozbeszerzes.ceu.hu/tender/2009/00/21214.xml
# http://kozbeszerzes.ceu.hu/tender/2012/00/17309.xml
# http://kozbeszerzes.ceu.hu/tender/2011/00/952.xml
# http://kozbeszerzes.ceu.hu/tender/2013/00/18997.xml
# http://kozbeszerzes.ceu.hu/tender/2012/00/7993.xml
# http://kozbeszerzes.ceu.hu/tender/2013/00/23532.xml
# http://kozbeszerzes.ceu.hu/tender/2009/00/12317.xml
# http://kozbeszerzes.ceu.hu/tender/2009/00/17014.xml
# http://kozbeszerzes.ceu.hu/tender/2013/00/1050.xml
# http://kozbeszerzes.ceu.hu/tender/2011/00/10553.xml
# http://kozbeszerzes.ceu.hu/tender/2011/00/28797.xml
# http://kozbeszerzes.ceu.hu/tender/2009/00/24354.xml
# http://kozbeszerzes.ceu.hu/tender/2002/48/9656.xml
# http://kozbeszerzes.ceu.hu/tender/2012/00/7910.xml
# http://kozbeszerzes.ceu.hu/tender/2009/00/9461.xml
# http://kozbeszerzes.ceu.hu/tender/2011/00/17068.xml
# http://kozbeszerzes.ceu.hu/tender/2011/00/10653.xml
# http://kozbeszerzes.ceu.hu/tender/2013/00/7986.xml
# http://kozbeszerzes.ceu.hu/tender/2009/00/30102.xml
# http://kozbeszerzes.ceu.hu/tender/2013/00/18457.xml
# http://kozbeszerzes.ceu.hu/tender/2009/00/24871.xml
# http://kozbeszerzes.ceu.hu/tender/2012/00/9430.xml
# http://kozbeszerzes.ceu.hu/tender/2013/00/9982.xml
# http://kozbeszerzes.ceu.hu/tender/2012/00/8779.xml
# http://kozbeszerzes.ceu.hu/tender/2013/00/23522.xml
# http://kozbeszerzes.ceu.hu/tender/2009/00/8257.xml
# http://kozbeszerzes.ceu.hu/tender/2011/00/32380.xml
# http://kozbeszerzes.ceu.hu/tender/2013/00/14596.xml
# http://kozbeszerzes.ceu.hu/tender/2011/00/13308.xml
# http://kozbeszerzes.ceu.hu/tender/2013/00/22874.xml
# http://kozbeszerzes.ceu.hu/tender/2012/00/2817.xml
# http://kozbeszerzes.ceu.hu/tender/2011/00/21958.xml
# http://kozbeszerzes.ceu.hu/tender/2013/00/15826.xml
# http://kozbeszerzes.ceu.hu/tender/2013/00/18941.xml
# http://kozbeszerzes.ceu.hu/tender/2012/00/11631.xml
# http://kozbeszerzes.ceu.hu/tender/2010/00/8316.xml
# http://kozbeszerzes.ceu.hu/tender/2009/00/15598.xml
# http://kozbeszerzes.ceu.hu/tender/2011/00/3678.xml
# http://kozbeszerzes.ceu.hu/tender/2012/00/20155.xml
# http://kozbeszerzes.ceu.hu/tender/2013/00/12835.xml
# http://kozbeszerzes.ceu.hu/tender/2013/00/164.xml
# http://kozbeszerzes.ceu.hu/tender/2013/00/6162.xml
# http://kozbeszerzes.ceu.hu/tender/2013/00/4625.xml
# http://kozbeszerzes.ceu.hu/tender/2013/00/395.xml
# http://kozbeszerzes.ceu.hu/tender/2007/00/17095.xml
# http://kozbeszerzes.ceu.hu/tender/2013/00/6207.xml
# http://kozbeszerzes.ceu.hu/tender/2008/00/10257.xml
# http://kozbeszerzes.ceu.hu/tender/2013/00/11921.xml
# http://kozbeszerzes.ceu.hu/tender/2010/00/6608.xml
# http://kozbeszerzes.ceu.hu/tender/2013/00/16314.xml

# %%
# parse the first tender
tender_response = requests.get(
    BASE_URL + soup.find('all_tenders_won').find('tender')['url']
)
if not tender_response.status_code == 200:
    print 'Tender download failed!'
else:
    tender_soup = BeautifulSoup(tender_response.content)
    print tender_soup.prettify()
# Out:
# <html>
#  <body>
#   <tender estimated_value="400000000" id="2013_00_157" requestor_city="Budapest" requestor_name="MÁV Rt" source_url="http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_157_2013" subject="A MÁV Zrt. vasúti hidak és acélszerkezetek felújítása és állagmegóvása - kivitelezés tárgyú keretmegállapodás alapján az alábbi munkák vállalkozásba adása : 5B. RÉSZ (MÁV VII. csomag / B rész)" url="/tender/2013/00/157.xml" year="2013">
#    <proceduretype>
#     Ajánlati/részvételi felhívás közzététele nélküli/hirdetmény nélküli tárgyalásos
#    </proceduretype>
#    <estimatedvalue>
#     400000000
#    </estimatedvalue>
#    <press>
#     2013/5
#    </press>
#    <requestor city="Budapest" id="t_10856417" name="MÁV Rt" url="/entity/t/10856417.xml">
#    </requestor>
#    <parts>
#     <part id="2013_00_157_1">
#      <allbidders>
#      </allbidders>
#      <currency>
#       HUF
#      </currency>
#      <decisiondate>
#       2012/12/14
#      </decisiondate>
#      <estimatedvalue>
#       400000000
#      </estimatedvalue>
#      <numberofbidder>
#       2
#      </numberofbidder>
#      <partid>
#       1
#      </partid>
#      <runnerupvalue>
#      </runnerupvalue>
#      <subject>
#       A MÁV Zrt. vasúti hidak és acélszerkezetek felújítása és állagmegóvása - kivitelezés tárgyú keretmegállapodás alapján az alábbi munkák vállalkozásba adása : 5B. RÉSZ (MÁV VII. csomag / B rész)
#      </subject>
#      <value>
#       345803000
#      </value>
#      <vat>
#       netto
#      </vat>
#      <winner city="Budapest" id="t_10950676" name="KÖZGÉP Zrt" url="/entity/t/10950676.xml">
#       <bestguessvalue>
#        345803000
#       </bestguessvalue>
#      </winner>
#      <best_guess_value>
#       345803000
#      </best_guess_value>
#     </part>
#    </parts>
#    <publicationdate>
#     2013/01/14
#    </publicationdate>
#    <proposaldate>
#     2011/05/21
#    </proposaldate>
#    <source_url>
#     http://www.kozbeszerzes.hu/adatbazis/mutat/hirdetmeny/portal_157_2013
#    </source_url>
#    <cpv>
#     45221100-3;45221112-0;45234100-7
#    </cpv>
#    <subject>
#     A MÁV Zrt. vasúti hidak és acélszerkezetek felújítása és állagmegóvása - kivitelezés tárgyú keretmegállapodás alapján az alábbi munkák vállalkozásba adása : 5B. RÉSZ (MÁV VII. csomag / B rész)
#    </subject>
#   </tender>
#  </body>
# </html>

# %%
# create a function, and get the needed information out of the xml
def get_tenders(base_url, sub_url):
    response = requests.get(base_url + sub_url)
    if not response.status_code == 200:
        print 'Download failed!'
    else:
        won_tenders = [['Year', 'Value', 'Desc']] # init with headers
        soup = BeautifulSoup(response.content)
        for tender in soup.find('all_tenders_won').findAll('tender'):
            tender_response = requests.get(base_url + tender['url'])
            if not tender_response.status_code == 200:
                print 'Tender download failed!'
            else:
                tender_soup = BeautifulSoup(tender_response.content)
                won_tenders.append([
                    tender_soup.find('tender')['year'],
                    tender_soup.find('tender')['estimated_value'],
                    '"' + tender_soup.find('tender')['subject'] + '"' # we use " to make sure that the data is wrapped
                ])
        return won_tenders

# %%
# write a save function
# since we have hungarian text, we need to encode our characters in UTF-8
# and unfortunately csv module does not support that
import codecs
def save_results(filename, tenders):
    with codecs.open(filename, 'w', 'utf-8') as output:
        for tender in tenders:
            output.write(u';'.join(tender) + u'\n')

# %%
# write a main function
def main():
    save_results('kozgep.csv', get_tenders(BASE_URL, kozgep_suburl))

# %%
# execute
main()

# %% [markdown]
# ---

# %% [markdown]
# ### Intermission: Creating a standalone script

# %%
# Intermission
from IPython.display import YouTubeVideo
YouTubeVideo("O0wOD9TWynM", autoplay=1)
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/O0wOD9TWynM?autoplay=1"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# Create a new text file with .py extension! You can specify the filename.
# Start it with:
#     `# encoding: utf-8`
# then copy-paste:
#     - the imports,
#     - the global variables
#     - the three functions
# and insert the following two lines into the end of the file:
# `if __name__ == '__main__':
#      main()`
# Save it, and now you can execute this script by invoking:
#     `python your_specified_filename.py`

# %%
# You can even import your newly created script:
import myscript # use your filename

# %%
# get it's contents
dir(myscript)
# Out:
# ['BASE_URL',
#  'BeautifulSoup',
#  '__builtins__',
#  '__doc__',
#  '__file__',
#  '__name__',
#  '__package__',
#  'codecs',
#  'get_tenders',
#  'kozgep_suburl',
#  'main',
#  'requests',
#  'save_results']

# %%
# print its variables
print myscript.BASE_URL
# Out:
# http://kozbeszerzes.ceu.hu

# %%
# use its functions
tenders = myscript.get_tenders(myscript.BASE_URL, myscript.kozgep_suburl)

# %%
myscript.save_results('kozgep1.csv', tenders)

# %% [markdown]
# ---

# %% [markdown]
# ### Act II: Disguise yourself!
#
# Let's pretend to be a browser instead of a script

# %%
USER_AGENTS = [
    # Chrome
    'Mozilla/5.0 (Windows NT 6.2; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/32.0.1667.0 Safari/537.36',
    # Firefox
    'Mozilla/5.0 (Windows NT 6.1; Win64; x64; rv:25.0) Gecko/20100101 Firefox/25.0',
    # Opera
    'Opera/9.80 (Windows NT 6.0) Presto/2.12.388 Version/12.14',
    # Safari
    'Mozilla/5.0 (iPad; CPU OS 6_0 like Mac OS X) AppleWebKit/536.26 (KHTML, like Gecko) Version/6.0 Mobile/10A5355d Safari/8536.25',
    # Internet Explorer, probably a good idea to leave this one out...
    'Mozilla/5.0 (compatible; MSIE 10.6; Windows NT 6.1; Trident/5.0; InfoPath.2; SLCC1; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729; .NET CLR 2.0.50727) 3gpp-gba UNTRUSTED/1.0',
]

# %%
# write a wrapper function to handle the user-agent string
import random
def get_header(agents):
    return {'User-agent': random.choice(agents)}

# %% [markdown]
# Get the main articles from index.hu

# %%
url = 'http://index.hu'
index_response = requests.get(url, headers=get_header(USER_AGENTS))

# %%
# study the skeleton of the site
soup = BeautifulSoup(index_response.content)
print soup.prettify()

# %%
# get the "front page"
index_main = soup.find('section', {'class': 'blokk hajtas-felett normal-vezeto-blokk normal-vezeto cimlap-blokk-index saved'})

# %%
# print the basics about the main articles
for article in index_main.findAll('article'):
    print ''
    # article image if exists
    if article.find('img'):
        print '[', article.find('img').get('src'), ']'
    # title
    print article.find('h1', {'class': 'cikkcim'}).getText()
    # link
    print '<', article.find('h1', {'class': 'cikkcim'}).find('a').get('href'), '>'
    # promo text if exists
    if article.find('p', {'class': 'ajanlo'}):
        print article.find('p', {'class': 'ajanlo'}).getText()
    print '-' * 79

# %% [markdown]
# Let's get the article texts, and the list of images for each "main" article!

# %%
articles = []
for article in index_main.findAll('article'):
    article_response = requests.get(
        article.find('h1', {'class': 'cikkcim'}).find('a').get('href'),
        headers=get_header(USER_AGENTS)
    )
    soup = BeautifulSoup(article_response.content)
    article_container = soup.find('div', {'class':'cikk-torzs-container'})
    if article_container:
        title = article.find('h1', {'class': 'cikkcim'}).getText()
        text = u'\n'.join([p.getText() for p in article_container.findAll('p')])
        images = [url.get('src') for url in article_container.findAll('img')]
        articles.append([title, text, images])

# %%
for article in articles:
    print ''
    print 'Title:', article[0]
    print 'Text:', article[1]
    print 'Images:'
    for img in article[2]:
        print img
    print '-' * 79

# %% [markdown]
# ### Final Act: Your turn!

# %% [markdown]
# Write a script called `youtube.py`, in which you create an object called RelatedTube.
# It has an attribute: `base_url` (youtube's base url)
# It has three functions: `init`, `get`, and `set`
#
# Init:
#     - Arguments: (`self` and) `youtube_video_id`
#     - Output: -
#     - Workflow: set the `self.video` to `youtube_video_id`
# Get:
#     - Arguments: `self`
#     - Output: the links to the related videos
#     - Workflow:
#         * get the `self.video` page
#         * parse it for the related links
#         * return them in a list
# Set:
#     - Arguments: (`self` and) `youtube_video_id`
#     - Output: -
#     - Workflow: set the `self.video` to `youtube_video_id`
# Don't forget to hide your a**!!!

# %%
# test the script
import youtube

# %%
related = youtube.RelatedTube('PIxZmbHzPeM')

# %%
# in case we have to restart the kernel... :D
from IPython.display import YouTubeVideo

# %%
for video in related.get():
    print video
